# %% [markdown]
# <a href="https://colab.research.google.com/github/HarikaLingamsetty/Machine-Learning/blob/main/Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# IMPORTING THE DATASET

# %%
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# VISUALIZING UNIVARIATE CONTINUOUS DATA

# %% [markdown]
# 1. UNIVARIATE SCATTER PLOT

# %%
plt.scatter(df.index, df['sepal.length'])
plt.show()

# %%
sns.scatterplot(x = df.index, y= df['sepal.length'], hue= df['variety'])
# Out:
# <Axes: ylabel='sepal.length'>

# %% [markdown]
# 2.LINE PLOT

# %%
plt.figure(figsize = (5,5))
plt.title('Line plot of petal length')
plt.xlabel('index', fontsize = 15)
plt.ylabel('petal length', fontsize = 15)
plt.plot(df.index, df['petal.length'], markevery = 1, marker = 'd')
for name, group in df.groupby('variety'):
  plt.plot(group.index, group['petal.length'], label = name, markevery = 1, marker = 'd')
plt.legend()
plt.show()

# %%
sns.set(rc={'figure.figsize':(5,5)})
sns.set(font_scale = 1.5)
fig= sns.lineplot(x = df.index, y = df['petal.length'], markevery = 1, marker ='d', data = df, hue= df['variety'])
fig.set(xlabel = 'index')
# Out:
# [Text(0.5, 0, 'index')]

# %% [markdown]
# 3.HISTOGRAMS

# %%
plt.hist(df['petal.width'])
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['petal.width'], kde = False, color = 'black', bins = 10)
# Out:
# <ipython-input-66-e7b6ced4ed21>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal.width'], kde = False, color = 'black', bins = 10)
# <Axes: xlabel='petal.width'>

# %% [markdown]
# 4. DENSITY PLOTS

# %%
df['petal.length'].plot(kind = 'density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(df['petal.length'], shade = True)
# Out:
# <ipython-input-68-49c58e969361>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['petal.length'], shade = True)
# <Axes: xlabel='petal.length', ylabel='Density'>

# %% [markdown]
# 5. BOX PLOTS

# %%
plt.boxplot(df['sepal.width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb24eb7dbd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb24eb7e860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb24eb7cb20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb24eb7f9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb24eb7f790>],
#  'means': []}

# %%
df2 = df.drop('variety', axis = 1)
plt.title('Box plots of variables')
plt.boxplot(df2.values, labels = ['SL','SW','PL','PW'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb25333b490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fb2508f0730>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb2532db070>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fb250505870>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb24f3d0be0>,
# ...
#  'means': []}

# %%
sns.boxplot(df['sepal.width'])
# Out:
# <Axes: >

# %%
sns.boxplot(x = "variable", y ="value", data = pd.melt(df2))
# Out:
# <Axes: xlabel='variable', ylabel='value'>

# %% [markdown]
# VISUALIZING CATEGORICAL VARIABLES

# %% [markdown]
# 1. BAR CHART

# %%
df['variety'].value_counts().plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# 2. PIE CHART

# %%
plt.pie(df['variety'].value_counts(), labels= ['SETOSA','VERSICOLOR', 'VIRGINICA'],shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb24e4c64d0>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'SETOSA'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'VERSICOLOR'),
#   Text(0.5500001486524352, -0.9526278583383436, 'VIRGINICA')])

# %%
df3 = df.sample(frac = 0.35)
plt.pie(df['variety'].value_counts(), startangle = 90, autopct ='%.3f',labels= ['SETOSA','VERSICOLOR', 'VIRGINICA'],shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fb24e372e30>,
# ...
#  [Text(-0.9526279613277876, 0.5499999702695114, 'SETOSA'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'VERSICOLOR'),
#   Text(0.9526278583383436, 0.5500001486524351, 'VIRGINICA')],
#  [Text(-0.5196152516333387, 0.29999998378336984, '33.333'),
#   Text(5.61760540981606e-08, -0.5999999999999974, '33.333'),
#   Text(0.5196151954572783, 0.3000000810831464, '33.333')])
